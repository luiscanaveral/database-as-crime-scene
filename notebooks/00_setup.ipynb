# %%
# %load_ext sql
# %load_ext autoreload
# %load_ext rich
# Out:
# Tip: You may define configurations in /app/pyproject.toml or /root/.jupysql/config.
# Please review our <a href='https://jupysql.ploomber.io/en/latest/api/configuration.html#loading-from-a-file'>configuration guideline</a>.
# Did not find user configurations in /app/pyproject.toml.

# %%
from rich import inspect
from rich.pretty import pprint

# %%
from database_as_crime_scene.notebook import DatabaseAsCrimeScene

DatabaseAsCrimeScene().setup()
# Out:
# Hola
