# %% [markdown]
# # see

# %%
# %env
# Out:
# {'SHELL': '/bin/bash',
#  'DB_PASSWORD': 'postgres',
#  'HOSTNAME': 'a59cecbf4315',
#  'LANGUAGE': 'en_US.UTF-8',
#  'NB_UID': '1000',
#  'PWD': '/home/jovyan',
#  'DB_PORT': '5432',
#  'DB_USER': 'postgres',
#  'HOME': '/home/jovyan',
#  'LANG': 'en_US.UTF-8',
#  'NB_GID': '100',
#  'DB_HOST': 'host.docker.internal',
#  'SHLVL': '0',
#  'CONDA_DIR': '/opt/conda',
#  'JUPYTER_PORT': '8888',
#  'DB_NAME': 'mydb',
#  'NB_USER': 'jovyan',
#  'LC_ALL': 'en_US.UTF-8',
#  'PATH': '/opt/conda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin',
#  'DEBIAN_FRONTEND': 'noninteractive',
#  'JPY_SESSION_NAME': '/home/jovyan/work/discovery.ipynb',
#  'JPY_PARENT_PID': '7',
#  'PYDEVD_USE_FRAME_EVAL': 'NO',
#  'TERM': 'xterm-color',
#  'CLICOLOR': '1',
#  'FORCE_COLOR': '1',
#  'CLICOLOR_FORCE': '1',
#  'PAGER': 'cat',
#  'GIT_PAGER': 'cat',
#  'MPLBACKEND': 'module://matplotlib_inline.backend_inline'}

# %%
import os

DB_HOST = os.getenv("DB_HOST")
DB_PORT = os.getenv("DB_PORT")
DB_NAME = os.getenv("DB_NAME")
DB_USER = os.getenv("DB_USER")
DB_PASSWORD = os.getenv("DB_PASSWORD")

def get_connection_string()->str:
    return f"postgresql://{DB_HOST}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_PASSWORD}"

print(get_connection_string())
# Out:
# postgresql://host.docker.internal:postgres@host.docker.internal:5432/postgres

# %%
from database_as_crime_scene import Notebook
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from database_as_crime_scene import Notebook
#
# ImportError: cannot import name 'Notebook' from 'database_as_crime_scene' (/home/jovyan/work/database_as_crime_scene/__init__.py)
